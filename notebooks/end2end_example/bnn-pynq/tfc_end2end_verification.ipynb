# %% [markdown]
# # FINN - Functional Verification of End-to-End Flow
# -----------------------------------------------------------------
#
# **Important: This notebook depends on the [tfc_end2end_example](tfc_end2end_example.ipynb) notebook, because we are using models that are available at intermediate steps in the end-to-end flow. So please make sure the needed .onnx files are generated to run this notebook.**
#
# In this notebook, we will show how to take the intermediate results of the end-to-end tfc example and verify their functionality with different methods. In the following picture you can see the section in the end-to-end flow about the *Simulation & Emulation Flows*.

# %% [markdown]
# <img src="verification.svg" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# We will use the following helper functions, `showSrc` to show source code of FINN library calls and `showInNetron` to show the ONNX model at the current transformation step. The Netron displays are interactive, but they only work when running the notebook actively and not on GitHub (i.e. if you are viewing this on GitHub you'll only see blank squares).

# %%
from finn.util.basic import make_build_dir
from finn.util.visualization import showSrc, showInNetron
import os

build_dir = os.environ["FINN_BUILD_DIR"]

# %% [markdown]
# To verify the simulations, a "golden" output is calculated as a reference. This is calculated directly from the Brevitas model using PyTorch, by running some example data from the MNIST dataset through the trained model.

# %%
from pkgutil import get_data
import onnx
import onnx.numpy_helper as nph
import torch
from finn.util.test import get_test_model_trained

fc = get_test_model_trained("TFC", 1, 1)
raw_i = get_data("qonnx.data", "onnx/mnist-conv/test_data_set_0/input_0.pb")
input_tensor = onnx.load_tensor_from_string(raw_i)
input_brevitas = torch.from_numpy(nph.to_array(input_tensor).copy()).float()
output_golden = fc.forward(input_brevitas).detach().numpy()
output_golden
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1255: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at ../c10/core/TensorImpl.h:1758.)
#   return super(Tensor, self).rename(names)
# array([[-1.4090618, -1.3267527,  0.9779036, -1.2444434, -1.4090618,
#         -1.6559892, -1.3267527, -1.4913709, -1.3267527, -1.6559892]],
#       dtype=float32)

# %% [markdown]
# ## Simulation using Python <a id='simpy'></a>
#
# If an ONNX model consists of [standard ONNX](https://github.com/onnx/onnx/blob/main/docs/Operators.md) nodes and/or FINN custom operations that do not belong to the fpgadataflow (`backend` $\neq$ `fpgadataflow.hls` or `backend` $\neq$ `fpgadataflow.rtl`) this model can be checked for functionality using Python.
#
# To simulate a standard ONNX node [onnxruntime](https://github.com/microsoft/onnxruntime) is used. onnxruntime is an open source tool developed by Microsoft to run standard ONNX nodes. For the FINN custom op nodes execution, functions are defined. The following is an example of the execution function of an XNOR popcount node.

# %%
from qonnx.custom_op.general.xnorpopcount import xnorpopcountmatmul
showSrc(xnorpopcountmatmul)
# Out:
# def xnorpopcountmatmul(inp0, inp1):
#     """Simulates XNOR-popcount matrix multiplication as a regular bipolar
#     matrix multiplication followed by some post processing."""
#     # extract the operand shapes
#     # (M, K0) = inp0.shape
#     # (K1, N) = inp1.shape
#     K0 = inp0.shape[-1]
#     K1 = inp1.shape[0]
#     # make sure shapes are compatible with matmul
#     assert K0 == K1, "Matrix shapes are not compatible with matmul."
#     K = K0
#     # convert binary inputs to bipolar
#     inp0_bipolar = 2.0 * inp0 - 1.0
#     inp1_bipolar = 2.0 * inp1 - 1.0
#     # call regular numpy matrix multiplication
#     out = np.matmul(inp0_bipolar, inp1_bipolar)
#     # XNOR-popcount does not produce the regular dot product result --
#     # it returns the number of +1s after XNOR. let P be the number of +1s
#     # and N be the number of -1s. XNOR-popcount returns P, whereas the
#     # regular dot product result from numpy is P-N, so we need to apply
#     # some correction.
#     # out = P-N
#     # K = P+N
#     # out + K = 2P, so P = (out + K)/2
#     return (out + K) * 0.5

# %% [markdown]
# The function contains a description of the behaviour in Python and can thus calculate the result of the node.
#
# This execution function and onnxruntime is used when `execute_onnx` from `onnx_exec` is applied to the model. The model is then simulated node by node and the result is stored in a context dictionary, which contains the values of each tensor at the end of the execution. To get the result, only the output tensor has to be extracted.
#
# The procedure is shown below. We take the model right before the nodes should be converted into HW layers and generate an input tensor to pass to the execution function. The input tensor is generated from the Brevitas example inputs.

# %%
import numpy as np
from qonnx.core.modelwrapper import ModelWrapper
input_dict = {"global_in": nph.to_array(input_tensor)}

model_for_sim = ModelWrapper(build_dir+"/tfc_w1a1_ready_for_hw_conversion.onnx")

# %%
import finn.core.onnx_exec as oxe
output_dict = oxe.execute_onnx(model_for_sim, input_dict, return_full_exec_context=False)
output_pysim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_pysim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# The result is compared with the theoretical "golden" value for verification.

# %% [markdown]
# ## Simulation (cppsim) using C++
#
# When dealing with HLS or RTL custom op nodes in FINN the simulation using Python is no longer sufficient. If the nodes are specialized to HLS layers, the simulation using C++ can be used. To do this, the input tensor is stored in a .npy file and C++ code is generated that reads the values from the .npy array, streams them to the corresponding `finn-hlslib` function and writes the result to a new .npy file. This in turn can be read in Python and processed in the FINN flow. For this example the model after setting the folding factors in the HLS variants of the layers, please be aware that this is not the full model, but the dataflow partition, so before executing at the end of this section we have to integrate the model back into the parent model.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note: HW layer can also be converted to RTL variants, in this case "cppsim" is not an option we can execute. If nevertheless "cppsim" is selected as execution mode for the layer, the execution defaults to the parent class. Like this, networks with a mix of HLS and RTL layers can be executed using "cppsim" for the HLS layers.</b>
# </div>

# %%
model_for_cppsim = ModelWrapper(build_dir+"/tfc_w1_a1_set_folding_factors.onnx")

# %% [markdown]
# To generate the code for this simulation and to generate the executable two transformations are used:
# * `PrepareCppSim` which generates the C++ code for the corresponding HLS layer
# * `CompileCppSim` which compules the C++ code and stores the path to the executable

# %%
from finn.transformation.fpgadataflow.prepare_cppsim import PrepareCppSim
from finn.transformation.fpgadataflow.compile_cppsim import CompileCppSim
from qonnx.transformation.general import GiveUniqueNodeNames

model_for_cppsim = model_for_cppsim.transform(GiveUniqueNodeNames())
model_for_cppsim = model_for_cppsim.transform(PrepareCppSim())
model_for_cppsim = model_for_cppsim.transform(CompileCppSim())

# %% [markdown]
# When we take a look at the model using netron, we can see that the transformations introduced new attributes.

# %%
model_for_cppsim.save(build_dir+"/tfc_w1_a1_for_cppsim.onnx")
showInNetron(build_dir+"/tfc_w1_a1_for_cppsim.onnx")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 model_for_cppsim.save(build_dir+"/tfc_w1_a1_for_cppsim.onnx")
# ----> 2 showInNetron(build_dir+"/tfc_w1_a1_for_cppsim.onnx")
#
# File /srv/homes/ipanagou/thesis/finn/src/finn/util/visualization.py:61, in showInNetron(model_filename, localhost_url, port)
#      59     port = 8081
#      60 localhost_url = localhost_url or os.getenv("LOCALHOST_URL", default="localhost")
# ---> 61 netron.start(model_filename, address=("0.0.0.0", port), browse=False)
#      62 return IFrame(src=f"http://{localhost_url}:{port}/", width="100%", height=400)
#
# File /usr/local/lib/python3.10/dist-packages/netron/server.py:322, in start(file, address, browse, verbosity)
#     310 def start(file=None, address=None, browse=True, verbosity=1):
#     311     '''Start serving model file at address and open in web browser.
#     312
#     313     Args:
#    (...)
#     320         A (host, port) address tuple.
#     321     '''
# --> 322     return serve(file, None, browse=browse, address=address, verbosity=verbosity)
#
# File /usr/local/lib/python3.10/dist-packages/netron/server.py:299, in serve(file, data, address, browse, verbosity)
#     296 else:
#     297     address = _make_port(address)
# --> 299 thread = _HTTPServerThread(content, address, verbosity)
#     300 thread.start()
#     301 while not thread.alive():
#
# File /usr/local/lib/python3.10/dist-packages/netron/server.py:130, in _HTTPServerThread.__init__(self, content, address, verbosity)
#     128 self.address = address
#     129 self.url = 'http://' + address[0] + ':' + str(address[1])
# --> 130 self.server = _ThreadedHTTPServer(address, _HTTPRequestHandler)
#     131 self.server.timeout = 0.25
#     132 self.server.block_on_close = False
#
# File /usr/lib/python3.10/socketserver.py:452, in TCPServer.__init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450 if bind_and_activate:
#     451     try:
# --> 452         self.server_bind()
#     453         self.server_activate()
#     454     except:
#
# File /usr/lib/python3.10/http/server.py:137, in HTTPServer.server_bind(self)
#     135 def server_bind(self):
#     136     """Override server_bind to store the server name."""
# --> 137     socketserver.TCPServer.server_bind(self)
#     138     host, port = self.server_address[:2]
#     139     self.server_name = socket.getfqdn(host)
#
# File /usr/lib/python3.10/socketserver.py:466, in TCPServer.server_bind(self)
#     464 if self.allow_reuse_address:
#     465     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466 self.socket.bind(self.server_address)
#     467 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 98] Address already in use

# %% [markdown]
# The following node attributes have been added:
# * `code_gen_dir_cppsim` indicates the directory where the files for the simulation using C++ are stored
# * `executable_path` specifies the path to the executable
#
# We take now a closer look into the files that were generated:

# %%
from qonnx.custom_op.registry import getCustomOp

fc0 = model_for_cppsim.graph.node[1]
fc0w = getCustomOp(fc0)
code_gen_dir = fc0w.get_nodeattr("code_gen_dir_cppsim")
# !ls {code_gen_dir}
# Out:
# compile.sh	      memblock.dat  thresh.h
# execute_MVAU_hls.cpp  node_model    weights.npy

# %% [markdown]
# Besides the .cpp file, the folder contains .h files with the weights and thresholds. The shell script contains the compile command and *node_model* is the executable generated by compilation. Comparing this with the `executable_path` node attribute, it can be seen that it specifies exactly the path to *node_model*.

# %% [markdown]
# To simulate the model the execution mode(exec_mode) must be set to "cppsim". This is done using the transformation SetExecMode.

# %%
from finn.transformation.fpgadataflow.set_exec_mode import SetExecMode

model_for_cppsim = model_for_cppsim.transform(SetExecMode("cppsim"))
model_for_cppsim.save(build_dir+"/tfc_w1_a1_for_cppsim.onnx")

# %% [markdown]
# Before the model can be executed using `execute_onnx`, we integrate the child model in the parent model. The function reads then the `exec_mode` and writes the input into the correct directory in a .npy file. To be able to read this in C++, there is an additional .hpp file ([npy2apintstream.hpp](https://github.com/Xilinx/finn/blob/main/src/finn/qnn-data/cpp/npy2apintstream.hpp)) in FINN, which uses cnpy to read .npy files and convert them into streams, or to read a stream and write it into an .npy. [cnpy](https://github.com/rogersce/cnpy) is a helper to read and write .npy and .npz formates in C++.
#
# The result is again compared to the "golden" output.

# %%
parent_model = ModelWrapper(build_dir+"/tfc_w1_a1_dataflow_parent.onnx")
sdp_node = parent_model.graph.node[1]
child_model = build_dir + "/tfc_w1_a1_for_cppsim.onnx"
getCustomOp(sdp_node).set_nodeattr("model", child_model)
output_dict = oxe.execute_onnx(parent_model, input_dict)
output_cppsim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_cppsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# ## Emulation (rtlsim) using PyVerilator
#
# The emulation using [PyVerilator](https://github.com/maltanar/pyverilator) can be done after IP blocks are generated from the corresponding HLS layers or for RTL layers directly using the generated Verilog files. Pyverilator is a tool which makes it possible to simulate verilog files using verilator via a python interface.
#
# We have two ways to use rtlsim, one is to run the model node-by-node as with the simulation methods, but if the model is in the form of the dataflow partition, the part of the graph that consist of only HLS/RTL nodes could also be executed as whole.

# %% [markdown]
# Because at the point where we want to grab and verify the model, the model is already in split form (parent graph consisting of non-hls layers and child graph consisting only of hls layers) we first have to reference the child graph within the parent graph. This is done using the node attribute `model` for the `StreamingDataflowPartition` node.
#
# First the procedure is shown, if the child graph has ip blocks corresponding to the individual layers, then the procedure is shown, if the child graph already has a stitched IP.

# %% [markdown]
# ### Emulation of model node-by-node
#
# The child model is loaded and the `exec_mode` for each node is set. To prepare the node-by-node emulation the transformation `PrepareRTLSim` is applied to the child model. With this transformation the emulation files are created for each node and can be used directly when calling `execute_onnx()`. Each node has a new node attribute "rtlsim_so" after transformation, which contains the path to the corresponding emulation files. Then it is saved in a new .onnx file so that the changed model can be referenced in the parent model.

# %%
from finn.transformation.fpgadataflow.prepare_rtlsim import PrepareRTLSim
from finn.transformation.fpgadataflow.prepare_ip import PrepareIP
from finn.transformation.fpgadataflow.hlssynth_ip import HLSSynthIP
from finn.util.basic import part_map

test_fpga_part = part_map["U250"]
target_clk_ns = 10

child_model = ModelWrapper(build_dir + "/tfc_w1_a1_set_folding_factors.onnx")
child_model = child_model.transform(GiveUniqueNodeNames())
child_model = child_model.transform(PrepareIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(HLSSynthIP())
child_model = child_model.transform(SetExecMode("rtlsim"))
child_model = child_model.transform(PrepareRTLSim())
child_model.save(build_dir + "/tfc_w1_a1_dataflow_child.onnx")
# Out:
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:56:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                          : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45.flow_control_loop_pipe_sequential_init_U
#    56 | #0 ap_loop_init_int = 1'b1;
#       |  ^
#                   ... For warning description see https://verilator.org/warn/STMTDLY?v=4.224
#                   ... Use "/* verilator lint_off STMTDLY */" and lint_on around source to disable this message.
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:57:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                          : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45.flow_control_loop_pipe_sequential_init_U
#    57 | #0 ap_done_cache = 1'b0;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:424:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                           : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   424 | #0 ap_CS_fsm = 1'd1;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:425:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                           : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   425 | #0 ap_done_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:587:23: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                          : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   587 |             ap_NS_fsm = 'bx;
#       |                       ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:608:35: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'ap_sig_allocacmp_block_1' generates 4 bits.
#                                                                                                                          : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   608 | assign conv2_i_i_i_cast_fu_109_p1 = ap_sig_allocacmp_block_1;
#       |                                   ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:693:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                           : ... In instance LabelSelect_hls_0
#   693 | #0 ap_CS_fsm = 5'd1;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:694:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                                           : ... In instance LabelSelect_hls_0
#   694 | #0 grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45_ap_start_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_LabelSelect_hls_0_ngwc0vet/LabelSelect_hls_0.v:841:23: Operator ASSIGN expects 5 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                          : ... In instance LabelSelect_hls_0
#   841 |             ap_NS_fsm = 'bx;
#       |                       ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:56:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                            : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30.flow_control_loop_pipe_sequential_init_U
#    56 | #0 ap_loop_init_int = 1'b1;
#       |  ^
#                   ... For warning description see https://verilator.org/warn/STMTDLY?v=4.224
#                   ... Use "/* verilator lint_off STMTDLY */" and lint_on around source to disable this message.
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:57:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                            : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30.flow_control_loop_pipe_sequential_init_U
#    57 | #0 ap_done_cache = 1'b0;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:924:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#   924 | #0 ap_CS_iter0_fsm = 1'd1;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:925:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#   925 | #0 ap_CS_iter1_fsm = 2'd1;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:926:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#   926 | #0 ap_done_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1152:29: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1152 |             ap_NS_iter0_fsm = 'bx;
#       |                             ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1176:29: Operator ASSIGN expects 2 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1176 |             ap_NS_iter1_fsm = 'bx;
#       |                             ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1899:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_21_fu_1209_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1899 | assign zext_ln169_10_fu_1215_p1 = add_ln169_21_fu_1209_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1901:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_22_fu_1219_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1901 | assign zext_ln169_11_fu_1225_p1 = add_ln169_22_fu_1219_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1903:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_25_fu_1433_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1903 | assign zext_ln169_12_fu_1439_p1 = add_ln169_25_fu_1433_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1905:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_27_fu_1449_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1905 | assign zext_ln169_13_fu_1455_p1 = add_ln169_27_fu_1449_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1907:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_29_fu_1465_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1907 | assign zext_ln169_14_fu_1471_p1 = add_ln169_29_fu_1465_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1909:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_30_fu_1475_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1909 | assign zext_ln169_15_fu_1481_p1 = add_ln169_30_fu_1475_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1911:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_33_fu_1689_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1911 | assign zext_ln169_16_fu_1695_p1 = add_ln169_33_fu_1689_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1913:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_35_fu_1705_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1913 | assign zext_ln169_17_fu_1711_p1 = add_ln169_35_fu_1705_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1915:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_37_fu_1721_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1915 | assign zext_ln169_18_fu_1727_p1 = add_ln169_37_fu_1721_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1917:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_38_fu_1731_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1917 | assign zext_ln169_19_fu_1737_p1 = add_ln169_38_fu_1731_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1919:31: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_3_fu_681_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1919 | assign zext_ln169_1_fu_687_p1 = add_ln169_3_fu_681_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1921:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_41_fu_1945_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1921 | assign zext_ln169_20_fu_1951_p1 = add_ln169_41_fu_1945_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1923:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_43_fu_1961_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1923 | assign zext_ln169_21_fu_1967_p1 = add_ln169_43_fu_1961_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1925:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_45_fu_1977_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1925 | assign zext_ln169_22_fu_1983_p1 = add_ln169_45_fu_1977_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1927:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_46_fu_1987_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1927 | assign zext_ln169_23_fu_1993_p1 = add_ln169_46_fu_1987_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1929:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_49_fu_2201_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1929 | assign zext_ln169_24_fu_2207_p1 = add_ln169_49_fu_2201_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1931:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_51_fu_2217_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1931 | assign zext_ln169_25_fu_2223_p1 = add_ln169_51_fu_2217_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1933:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_53_fu_2233_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1933 | assign zext_ln169_26_fu_2239_p1 = add_ln169_53_fu_2233_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1935:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_54_fu_2243_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1935 | assign zext_ln169_27_fu_2249_p1 = add_ln169_54_fu_2243_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1937:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_57_fu_2457_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1937 | assign zext_ln169_28_fu_2463_p1 = add_ln169_57_fu_2457_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1939:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_59_fu_2473_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1939 | assign zext_ln169_29_fu_2479_p1 = add_ln169_59_fu_2473_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1941:31: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_5_fu_697_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1941 | assign zext_ln169_2_fu_703_p1 = add_ln169_5_fu_697_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1943:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_61_fu_2489_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1943 | assign zext_ln169_30_fu_2495_p1 = add_ln169_61_fu_2489_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1945:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_62_fu_2499_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1945 | assign zext_ln169_31_fu_2505_p1 = add_ln169_62_fu_2499_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1947:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_65_fu_2713_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1947 | assign zext_ln169_32_fu_2719_p1 = add_ln169_65_fu_2713_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1949:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_67_fu_2729_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1949 | assign zext_ln169_33_fu_2735_p1 = add_ln169_67_fu_2729_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1951:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_69_fu_2745_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1951 | assign zext_ln169_34_fu_2751_p1 = add_ln169_69_fu_2745_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1953:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_70_fu_2755_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1953 | assign zext_ln169_35_fu_2761_p1 = add_ln169_70_fu_2755_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1955:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_73_fu_2969_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1955 | assign zext_ln169_36_fu_2975_p1 = add_ln169_73_fu_2969_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1957:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_75_fu_2985_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1957 | assign zext_ln169_37_fu_2991_p1 = add_ln169_75_fu_2985_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1959:33: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_77_fu_3001_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1959 | assign zext_ln169_38_fu_3007_p1 = add_ln169_77_fu_3001_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1961:33: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_78_fu_3011_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1961 | assign zext_ln169_39_fu_3017_p1 = add_ln169_78_fu_3011_p2;
#       |                                 ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1963:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_6_fu_707_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1963 | assign zext_ln169_3_fu_713_p1 = add_ln169_6_fu_707_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1965:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_9_fu_921_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1965 | assign zext_ln169_4_fu_927_p1 = add_ln169_9_fu_921_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1967:31: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_11_fu_937_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1967 | assign zext_ln169_5_fu_943_p1 = add_ln169_11_fu_937_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1969:31: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_13_fu_953_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1969 | assign zext_ln169_6_fu_959_p1 = add_ln169_13_fu_953_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1971:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_14_fu_963_p2' generates 3 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1971 | assign zext_ln169_7_fu_969_p1 = add_ln169_14_fu_963_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1973:32: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_17_fu_1177_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1973 | assign zext_ln169_8_fu_1183_p1 = add_ln169_17_fu_1177_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1975:32: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_19_fu_1193_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1975 | assign zext_ln169_9_fu_1199_p1 = add_ln169_19_fu_1193_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1977:29: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln169_1_fu_665_p2' generates 2 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1977 | assign zext_ln169_fu_671_p1 = add_ln169_1_fu_665_p2;
#       |                             ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1979:30: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_13_fu_879_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1979 | assign zext_ln68_1_fu_885_p1 = r_13_fu_879_p2;
#       |                              ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1981:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_21_fu_1135_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1981 | assign zext_ln68_2_fu_1141_p1 = r_21_fu_1135_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1983:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_29_fu_1391_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1983 | assign zext_ln68_3_fu_1397_p1 = r_29_fu_1391_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1985:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_37_fu_1647_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1985 | assign zext_ln68_4_fu_1653_p1 = r_37_fu_1647_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1987:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_45_fu_1903_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1987 | assign zext_ln68_5_fu_1909_p1 = r_45_fu_1903_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1989:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_53_fu_2159_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1989 | assign zext_ln68_6_fu_2165_p1 = r_53_fu_2159_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1991:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_61_fu_2415_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1991 | assign zext_ln68_7_fu_2421_p1 = r_61_fu_2415_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1993:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_69_fu_2671_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1993 | assign zext_ln68_8_fu_2677_p1 = r_69_fu_2671_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1995:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_77_fu_2927_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1995 | assign zext_ln68_9_fu_2933_p1 = r_77_fu_2927_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1997:28: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_5_fu_607_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1997 | assign zext_ln68_fu_613_p1 = r_5_fu_607_p2;
#       |                            ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:1999:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_11_fu_847_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1999 | assign zext_ln90_10_fu_853_p1 = r_11_fu_847_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2001:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_12_fu_863_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2001 | assign zext_ln90_11_fu_869_p1 = r_12_fu_863_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2003:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_14_fu_895_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2003 | assign zext_ln90_12_fu_901_p1 = r_14_fu_895_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2005:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_15_fu_911_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2005 | assign zext_ln90_13_fu_917_p1 = r_15_fu_911_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2007:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_16_fu_1055_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2007 | assign zext_ln90_14_fu_1061_p1 = r_16_fu_1055_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2009:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_17_fu_1071_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2009 | assign zext_ln90_15_fu_1077_p1 = r_17_fu_1071_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2011:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_18_fu_1087_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2011 | assign zext_ln90_16_fu_1093_p1 = r_18_fu_1087_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2013:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_19_fu_1103_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2013 | assign zext_ln90_17_fu_1109_p1 = r_19_fu_1103_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2015:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_20_fu_1119_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2015 | assign zext_ln90_18_fu_1125_p1 = r_20_fu_1119_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2017:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_22_fu_1151_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2017 | assign zext_ln90_19_fu_1157_p1 = r_22_fu_1151_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2019:30: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_1_fu_511_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2019 | assign zext_ln90_1_fu_517_p1 = r_1_fu_511_p2;
#       |                              ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2021:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_23_fu_1167_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2021 | assign zext_ln90_20_fu_1173_p1 = r_23_fu_1167_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2023:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_24_fu_1311_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2023 | assign zext_ln90_21_fu_1317_p1 = r_24_fu_1311_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2025:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_25_fu_1327_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2025 | assign zext_ln90_22_fu_1333_p1 = r_25_fu_1327_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2027:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_26_fu_1343_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2027 | assign zext_ln90_23_fu_1349_p1 = r_26_fu_1343_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2029:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_27_fu_1359_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2029 | assign zext_ln90_24_fu_1365_p1 = r_27_fu_1359_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2031:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_28_fu_1375_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2031 | assign zext_ln90_25_fu_1381_p1 = r_28_fu_1375_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2033:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_30_fu_1407_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2033 | assign zext_ln90_26_fu_1413_p1 = r_30_fu_1407_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2035:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_31_fu_1423_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2035 | assign zext_ln90_27_fu_1429_p1 = r_31_fu_1423_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2037:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_32_fu_1567_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2037 | assign zext_ln90_28_fu_1573_p1 = r_32_fu_1567_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2039:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_33_fu_1583_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2039 | assign zext_ln90_29_fu_1589_p1 = r_33_fu_1583_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2041:30: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_2_fu_535_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2041 | assign zext_ln90_2_fu_541_p1 = r_2_fu_535_p2;
#       |                              ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2043:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_34_fu_1599_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2043 | assign zext_ln90_30_fu_1605_p1 = r_34_fu_1599_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2045:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_35_fu_1615_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2045 | assign zext_ln90_31_fu_1621_p1 = r_35_fu_1615_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2047:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_36_fu_1631_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2047 | assign zext_ln90_32_fu_1637_p1 = r_36_fu_1631_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2049:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_38_fu_1663_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2049 | assign zext_ln90_33_fu_1669_p1 = r_38_fu_1663_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2051:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_39_fu_1679_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2051 | assign zext_ln90_34_fu_1685_p1 = r_39_fu_1679_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2053:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_40_fu_1823_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2053 | assign zext_ln90_35_fu_1829_p1 = r_40_fu_1823_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_3_1yxlyqss/MVAU_hls_3.v:2055:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_41_fu_1839_p2' generates 1 bits.
#                                                                                                             : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2055 | assign zext_ln90_36_fu_1845_p1 = r_41_fu_1839_p2;
# ...
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14940 | assign zext_ln90_8_fu_2955_p1 = r_8_fu_2949_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14942:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_90_fu_5383_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14942 | assign zext_ln90_90_fu_5389_p1 = r_90_fu_5383_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14944:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_91_fu_5399_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14944 | assign zext_ln90_91_fu_5405_p1 = r_91_fu_5399_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14946:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_92_fu_5415_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14946 | assign zext_ln90_92_fu_5421_p1 = r_92_fu_5415_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14948:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_93_fu_5431_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14948 | assign zext_ln90_93_fu_5437_p1 = r_93_fu_5431_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14950:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_94_fu_5447_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14950 | assign zext_ln90_94_fu_5453_p1 = r_94_fu_5447_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14952:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_95_fu_5463_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14952 | assign zext_ln90_95_fu_5469_p1 = r_95_fu_5463_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14954:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_96_fu_5479_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14954 | assign zext_ln90_96_fu_5485_p1 = r_96_fu_5479_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14956:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_97_fu_5495_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14956 | assign zext_ln90_97_fu_5501_p1 = r_97_fu_5495_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14958:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_98_fu_6313_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14958 | assign zext_ln90_98_fu_6319_p1 = r_98_fu_6313_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14960:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_99_fu_6329_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14960 | assign zext_ln90_99_fu_6335_p1 = r_99_fu_6329_p2;
#       |                                ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14962:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_9_fu_2973_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14962 | assign zext_ln90_9_fu_2979_p1 = r_9_fu_2973_p2;
#       |                               ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:14964:29: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_fu_2757_p2' generates 1 bits.
#                                                                                                              : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 14964 | assign zext_ln90_fu_2763_p1 = r_fu_2757_p2;
#       |                             ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:15048:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                               : ... In instance MVAU_hls_0
# 15048 | #0 grp_Matrix_Vector_Activate_Stream_Batch_fu_30_ap_start_reg = 1'b0;
#       |  ^
# %Warning-STMTDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:15049:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                               : ... In instance MVAU_hls_0
# 15049 | #0 ap_CS_fsm = 4'd1;
#       |  ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/rtlsim_MVAU_hls_0_lwmwb_yk/MVAU_hls_0.v:15191:23: Operator ASSIGN expects 4 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                              : ... In instance MVAU_hls_0
# 15191 |             ap_NS_fsm = 'bx;
#       |                       ^
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_2_h2oqfaf9'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_2_h2oqfaf9/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VMVAU_hls_2.cpp VMVAU_hls_2___024root__DepSet_h4cde490c__0.cpp VMVAU_hls_2__Trace__0.cpp VMVAU_hls_2__ConstPool_0.cpp VMVAU_hls_2___024root__Slow.cpp VMVAU_hls_2___024root__DepSet_h4cde490c__0__Slow.cpp VMVAU_hls_2__Syms.cpp VMVAU_hls_2__Trace__0__Slow.cpp > VMVAU_hls_2__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VMVAU_hls_2__ALL.o VMVAU_hls_2__ALL.cpp
# echo "" > VMVAU_hls_2__ALL.verilator_deplist.tmp
# Archive ar -rcs VMVAU_hls_2__ALL.a VMVAU_hls_2__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VMVAU_hls_2__ALL.a      -o VMVAU_hls_2
# rm VMVAU_hls_2__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_2_h2oqfaf9'
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_qkx7jlm_'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_qkx7jlm_/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VThresholding_hls_0.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0.cpp VThresholding_hls_0__Trace__0.cpp VThresholding_hls_0__ConstPool_0.cpp VThresholding_hls_0___024root__Slow.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0__Slow.cpp VThresholding_hls_0__Syms.cpp VThresholding_hls_0__Trace__0__Slow.cpp > VThresholding_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VThresholding_hls_0__ALL.o VThresholding_hls_0__ALL.cpp
# echo "" > VThresholding_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VThresholding_hls_0__ALL.a VThresholding_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VThresholding_hls_0__ALL.a      -o VThresholding_hls_0
# rm VThresholding_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_qkx7jlm_'
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_na1yptbv'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_na1yptbv/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VMVAU_hls_0.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0.cpp VMVAU_hls_0__Trace__0.cpp VMVAU_hls_0__ConstPool_0.cpp VMVAU_hls_0___024root__Slow.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0__Slow.cpp VMVAU_hls_0__Syms.cpp VMVAU_hls_0__Trace__0__Slow.cpp > VMVAU_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VMVAU_hls_0__ALL.o VMVAU_hls_0__ALL.cpp
# echo "" > VMVAU_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VMVAU_hls_0__ALL.a VMVAU_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VMVAU_hls_0__ALL.a      -o VMVAU_hls_0
# rm VMVAU_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_na1yptbv'

# %% [markdown]
# The next step is to load the parent model and set the node attribute `model` in the StreamingDataflowPartition node (`sdp_node`). Afterwards the `exec_mode` is set in the parent model in each node and the model can be executed.

# %%
# parent model
model_for_rtlsim = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_parent.onnx")
# reference child model
sdp_node = getCustomOp(model_for_rtlsim.graph.node[1])
sdp_node.set_nodeattr("model", build_dir + "/tfc_w1_a1_dataflow_child.onnx")

model_for_rtlsim = model_for_rtlsim.transform(SetExecMode("rtlsim"))

# %%
output_dict = oxe.execute_onnx(model_for_rtlsim, input_dict)
output_rtlsim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_rtlsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# ### Emulation of stitched IP
#
# Here we use the same procedure. First the child model is loaded, but in contrast to the layer-by-layer emulation, the metadata property `exec_mode` is set to "rtlsim" for the whole child model. When the model is integrated and executed in the last step, the verilog files of the stitched IP of the child model are used.

# %%
from finn.transformation.fpgadataflow.insert_dwc import InsertDWC
from finn.transformation.fpgadataflow.insert_fifo import InsertFIFO
from finn.transformation.fpgadataflow.specialize_layers import SpecializeLayers
from finn.transformation.fpgadataflow.create_stitched_ip import CreateStitchedIP

child_model = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_child.onnx")
child_model = child_model.transform(InsertDWC())  
child_model = child_model.transform(InsertFIFO(create_shallow_fifos=True))
# DWC and FIFOs need to be specialized to either HLS or RTL variants
child_model = child_model.transform(SpecializeLayers())
child_model.save(build_dir + "/test.onnx");
child_model = child_model.transform(GiveUniqueNodeNames())
child_model = child_model.transform(PrepareIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(HLSSynthIP())
child_model = child_model.transform(CreateStitchedIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(PrepareRTLSim())
child_model.set_metadata_prop("exec_mode","rtlsim")
child_model.save(build_dir + "/tfc_w1_a1_dataflow_child.onnx");
# Out:
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for Thresholding_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for LabelSelect_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_3
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for LabelSelect_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_2
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_1
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /srv/homes/ipanagou/thesis/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for Thresholding_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_v8ldyf6k/dwc.sv:106:4: Logical operator IF expects 1 bit on the If, but If's MODDIV generates 32 bits.
#                                                                                                                                    : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   106 |    if(IBITS % OBITS) begin
#       |    ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_v8ldyf6k/dwc.sv:135:11: Operator ASSIGN expects 5 bits on the Assign RHS, but Assign RHS's COND generates 32 bits.
#                                                                                                                                     : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   135 |      acnt = ivld? -K+1 : 1;
#       |           ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_v8ldyf6k/dwc.sv:141:18: Operator ADD expects 5 bits on the RHS, but RHS's VARREF 'ainc' generates 1 bits.
#                                                                                                                                     : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   141 |     ACnt <= acnt + ainc;
#       |                  ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:121:54: Operator EQ expects 32 or 2 bits on the LHS, but LHS's VARREF 'addr_' generates 1 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   121 |    assign addr_full_ = (state_==state_more) && (addr_==depth-2);
#       |                                                      ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:178:10: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's SUB generates 32 or 2 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   178 |   for (a_=depth-2; a_>0; a_=a_-1) begin
#       |          ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:186:21: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   186 |         srlo_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:189:21: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   189 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:202:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   202 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:212:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   212 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:226:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   226 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:233:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   233 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:246:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   246 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:264:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   264 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:278:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   278 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:295:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   295 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:298:16: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_8.impl
#   298 |    addr_       <=  'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/StreamingFIFO_rtl_8.v:62:3: Output port connection 'count' expects 2 bits on the pin connection, but pin connection's VARREF 'count' generates 1 bits.
#                                                                                                                                    : ... In instance StreamingFIFO_rtl_8
#    62 |  .count(count),
#       |   ^~~~~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/StreamingFIFO_rtl_8.v:63:3: Output port connection 'maxcount' expects 2 bits on the pin connection, but pin connection's VARREF 'maxcount' generates 1 bits.
#                                                                                                                                    : ... In instance StreamingFIFO_rtl_8
#    63 |  .maxcount(maxcount),
#       |   ^~~~~~~~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:186:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   186 |         srlo_       <=  'bx;
#       |                     ^~
#                   *** See https://verilator.org/warn/COMBDLY before disabling this,
#                   else you may end up with different sim results.
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:187:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   187 |         shift_en_o_ <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:188:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   188 |         shift_en_   <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:189:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   189 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:190:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   190 |         state_      <= 2'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:195:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   195 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:196:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   196 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:197:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   197 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:198:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   198 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:199:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   199 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:202:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   202 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:203:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   203 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:204:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   204 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:205:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   205 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:206:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   206 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:212:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   212 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:213:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   213 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:214:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   214 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:215:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   215 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:216:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   216 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:219:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   219 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:220:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   220 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:221:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   221 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:222:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   222 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:223:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   223 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:226:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   226 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:227:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   227 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:228:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   228 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:229:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   229 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:230:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   230 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:233:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   233 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:234:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   234 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:235:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   235 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:236:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   236 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:237:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   237 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:246:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   246 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:247:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   247 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:248:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   248 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:249:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   249 |    addr_       <= addr;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:250:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   250 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:253:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   253 |    srlo_       <= srl[addr];
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:254:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   254 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:255:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   255 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:258:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   258 |    addr_       <= addr_zero_ ? 0         : addr-1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:259:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   259 |    state_      <= addr_zero_ ? state_one : state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:295:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   295 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:296:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   296 |    shift_en_o_ <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:297:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   297 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:298:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   298 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_8_j3r6g8up/Q_srl.v:299:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   299 |    state_      <= 2'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:121:54: Operator EQ expects 32 or 2 bits on the LHS, but LHS's VARREF 'addr_' generates 1 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_7.impl
#   121 |    assign addr_full_ = (state_==state_more) && (addr_==depth-2);
#       |                                                      ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:178:10: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's SUB generates 32 or 2 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_7.impl
#   178 |   for (a_=depth-2; a_>0; a_=a_-1) begin
#       |          ^
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:189:21: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_7.impl
#   189 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:298:16: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                                        : ... In instance StreamingFIFO_rtl_7.impl
#   298 |    addr_       <=  'bx;
#       |                ^~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/StreamingFIFO_rtl_7.v:62:3: Output port connection 'count' expects 2 bits on the pin connection, but pin connection's VARREF 'count' generates 1 bits.
#                                                                                                                                    : ... In instance StreamingFIFO_rtl_7
#    62 |  .count(count),
#       |   ^~~~~
# %Warning-WIDTH: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/StreamingFIFO_rtl_7.v:63:3: Output port connection 'maxcount' expects 2 bits on the pin connection, but pin connection's VARREF 'maxcount' generates 1 bits.
#                                                                                                                                    : ... In instance StreamingFIFO_rtl_7
#    63 |  .maxcount(maxcount),
#       |   ^~~~~~~~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:186:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   186 |         srlo_       <=  'bx;
#       |                     ^~
#                   *** See https://verilator.org/warn/COMBDLY before disabling this,
#                   else you may end up with different sim results.
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:187:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   187 |         shift_en_o_ <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:188:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   188 |         shift_en_   <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:189:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   189 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:190:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   190 |         state_      <= 2'bx;
#       |                     ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:195:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   195 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:196:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   196 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:197:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   197 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:198:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   198 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:199:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   199 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:202:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   202 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:203:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   203 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:204:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   204 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:205:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   205 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:206:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   206 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:212:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   212 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:213:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   213 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:214:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   214 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:215:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   215 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:216:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   216 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:219:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   219 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:220:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   220 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:221:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   221 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:222:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   222 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:223:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   223 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:226:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   226 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:227:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   227 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:228:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   228 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_7_d6kcmmo6/Q_srl.v:229:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
# ...
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   250 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:253:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   253 |    srlo_       <= srl[addr];
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:254:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   254 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:255:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   255 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:258:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   258 |    addr_       <= addr_zero_ ? 0         : addr-1;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:259:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   259 |    state_      <= addr_zero_ ? state_one : state_more;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:295:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   295 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:296:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   296 |    shift_en_o_ <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:297:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   297 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:298:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   298 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/code_gen_ipgen_StreamingFIFO_rtl_0__ttl9dso/Q_srl.v:299:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                                          : ... This will be executed as a blocking assignment '='!
#   299 |    state_      <= 2'bx;
#       |                ^~
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_px0pxxie'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_px0pxxie/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VMVAU_hls_0.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0.cpp VMVAU_hls_0__Trace__0.cpp VMVAU_hls_0__ConstPool_0.cpp VMVAU_hls_0___024root__Slow.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0__Slow.cpp VMVAU_hls_0__Syms.cpp VMVAU_hls_0__Trace__0__Slow.cpp > VMVAU_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VMVAU_hls_0__ALL.o VMVAU_hls_0__ALL.cpp
# echo "" > VMVAU_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VMVAU_hls_0__ALL.a VMVAU_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VMVAU_hls_0__ALL.a      -o VMVAU_hls_0
# rm VMVAU_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_MVAU_hls_0_px0pxxie'
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_mqxrym0c'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_mqxrym0c/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VThresholding_hls_0.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0.cpp VThresholding_hls_0__Trace__0.cpp VThresholding_hls_0__ConstPool_0.cpp VThresholding_hls_0___024root__Slow.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0__Slow.cpp VThresholding_hls_0__Syms.cpp VThresholding_hls_0__Trace__0__Slow.cpp > VThresholding_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VThresholding_hls_0__ALL.o VThresholding_hls_0__ALL.cpp
# echo "" > VThresholding_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VThresholding_hls_0__ALL.a VThresholding_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VThresholding_hls_0__ALL.a      -o VThresholding_hls_0
# rm VThresholding_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_Thresholding_hls_0_mqxrym0c'
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_1_t652awc0'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_1_t652awc0/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFIFO_rtl_1.cpp VStreamingFIFO_rtl_1___024root__DepSet_h617ba1de__0.cpp VStreamingFIFO_rtl_1__Trace__0.cpp VStreamingFIFO_rtl_1___024root__Slow.cpp VStreamingFIFO_rtl_1___024root__DepSet_h617ba1de__0__Slow.cpp VStreamingFIFO_rtl_1__Syms.cpp VStreamingFIFO_rtl_1__Trace__0__Slow.cpp > VStreamingFIFO_rtl_1__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VStreamingFIFO_rtl_1__ALL.o VStreamingFIFO_rtl_1__ALL.cpp
# echo "" > VStreamingFIFO_rtl_1__ALL.verilator_deplist.tmp
# Archive ar -rcs VStreamingFIFO_rtl_1__ALL.a VStreamingFIFO_rtl_1__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VStreamingFIFO_rtl_1__ALL.a      -o VStreamingFIFO_rtl_1
# rm VStreamingFIFO_rtl_1__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_1_t652awc0'
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_0_cynxvik1'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_0_cynxvik1/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFIFO_rtl_0.cpp VStreamingFIFO_rtl_0___024root__DepSet_hb5df65a9__0.cpp VStreamingFIFO_rtl_0__Trace__0.cpp VStreamingFIFO_rtl_0__ConstPool_0.cpp VStreamingFIFO_rtl_0___024root__Slow.cpp VStreamingFIFO_rtl_0___024root__DepSet_hb5df65a9__0__Slow.cpp VStreamingFIFO_rtl_0__Syms.cpp VStreamingFIFO_rtl_0__Trace__0__Slow.cpp > VStreamingFIFO_rtl_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VStreamingFIFO_rtl_0__ALL.o VStreamingFIFO_rtl_0__ALL.cpp
# echo "" > VStreamingFIFO_rtl_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VStreamingFIFO_rtl_0__ALL.a VStreamingFIFO_rtl_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VStreamingFIFO_rtl_0__ALL.a      -o VStreamingFIFO_rtl_0
# rm VStreamingFIFO_rtl_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_StreamingFIFO_rtl_0_cynxvik1'

# %%
# parent model
model_for_rtlsim = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_parent.onnx")
# reference child model
sdp_node = getCustomOp(model_for_rtlsim.graph.node[1])
sdp_node.set_nodeattr("model", build_dir + "/tfc_w1_a1_dataflow_child.onnx")

# %%
output_dict = oxe.execute_onnx(model_for_rtlsim, input_dict)
output_rtlsim = output_dict[list(output_dict.keys())[0]]
# Out:
# %Warning-MODDUP: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:3389:8: Duplicate declaration of module: 'dwc'
#  3389 | module dwc #(
#       |        ^~~
#                  /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:608:8: ... Location of original declaration
#   608 | module dwc #(
#       |        ^~~
#                  ... For warning description see https://verilator.org/warn/MODDUP?v=4.224
#                  ... Use "/* verilator lint_off MODDUP */" and lint_on around source to disable this message.
# %Warning-MODDUP: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:32470:8: Duplicate declaration of module: 'dwc_axi'
# 32470 | module dwc_axi #(
#       |        ^~~~~~~
#                  /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:25491:8: ... Location of original declaration
# 25491 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn/finn-rtllib/swg/swg_pkg.sv:32:9: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#    32 | package swg;
#       |         ^~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:60:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#    60 | module finn_design_MVAU_hls_3_wstrm_0 (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:233:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   233 | module finn_design_MVAU_hls_2_wstrm_0 (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:381:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   381 | module StreamingFIFO_rtl_3(
#       |        ^~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:456:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   456 | module StreamingFIFO_rtl_4(
#       |        ^~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:531:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   531 | module StreamingFIFO_rtl_0(
#       |        ^~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:608:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   608 | module dwc #(
#       |        ^~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:807:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#   807 | module Q_srl (clock, reset, i_d, i_v, i_r, o_d, o_v, o_r, count, maxcount);
#       |        ^~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1104:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#  1104 | module finn_design_StreamingFIFO_rtl_6_0 (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1187:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#  1187 | module StreamingFIFO_rtl_7(
#       |        ^~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1288:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#  1288 | module finn_design_MVAU_hls_2_0 (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1382:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#  1382 | module memstream_axi #(
#       |        ^~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-TIMESCALEMOD: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1545:8: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#  1545 | module finn_design_MVAU_hls_0_wstrm_0 (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                        /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:1983:8: ... Location of module with timescale
#  1983 | module MVAU_hls_1_regslice_both
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-UNPACKED: /srv/homes/ipanagou/thesis/finn_dev_ipanagou/vivado_stitch_proj_6pwtnqse/finn_design_wrapper.v:2610:10: Unsupported: Unpacked struct/union
#                                                                                                                          : ... In instance finn_design_wrapper.finn_design_i.Thresholding_hls_0.Thresholding_hls_0_wstrm.inst.core.mem
#  2610 |  typedef struct {
#       |          ^~~~~~
# make: Entering directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_ipstitched_wrbijx4o'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_ipstitched_wrbijx4o/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper.o Vfinn_design_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper__Trace__0.o Vfinn_design_wrapper__Trace__0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__ConstPool_0.o Vfinn_design_wrapper__ConstPool_0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper___024root__Slow.o Vfinn_design_wrapper___024root__Slow.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1__Slow.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__Syms.o Vfinn_design_wrapper__Syms.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__Trace__0__Slow.o Vfinn_design_wrapper__Trace__0__Slow.cpp
# echo "" > Vfinn_design_wrapper__ALL.verilator_deplist.tmp
# Archive ar -rcs Vfinn_design_wrapper__ALL.a Vfinn_design_wrapper.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.o Vfinn_design_wrapper__Trace__0.o Vfinn_design_wrapper__ConstPool_0.o Vfinn_design_wrapper___024root__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1__Slow.o Vfinn_design_wrapper__Syms.o Vfinn_design_wrapper__Trace__0__Slow.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o Vfinn_design_wrapper__ALL.a      -o Vfinn_design_wrapper
# rm Vfinn_design_wrapper__ALL.verilator_deplist.tmp
# make: Leaving directory '/srv/homes/ipanagou/thesis/finn_dev_ipanagou/pyverilator_ipstitched_wrbijx4o'

# %%
try:
    assert np.isclose(output_rtlsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
